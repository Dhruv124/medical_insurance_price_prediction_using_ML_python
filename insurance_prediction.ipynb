# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as pt
import warnings
warnings.filterwarnings("ignore")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 import seaborn as sns
#       4 import matplotlib as pt
#       5 import warnings
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.6 MB 1.8 MB/s eta 0:00:07
#     --------------------------------------- 0.2/11.6 MB 1.8 MB/s eta 0:00:07
#    - -------------------------------------- 0.3/11.6 MB 1.8 MB/s eta 0:00:07
#    - -------------------------------------- 0.4/11.6 MB 1.7 MB/s eta 0:00:07
#    - -------------------------------------- 0.4/11.6 MB 1.6 MB/s eta 0:00:08
#    - -------------------------------------- 0.5/11.6 MB 1.8 MB/s eta 0:00:07
#    -- ------------------------------------- 0.6/11.6 MB 1.7 MB/s eta 0:00:07
#    -- ------------------------------------- 0.8/11.6 MB 1.8 MB/s eta 0:00:07
#    --- ------------------------------------ 0.9/11.6 MB 1.9 MB/s eta 0:00:06
#    --- ------------------------------------ 1.0/11.6 MB 1.9 MB/s eta 0:00:06
# ...

# %%
pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/294.9 kB 640.0 kB/s eta 0:00:01
#    ---------- ---------------------------- 81.9/294.9 kB 907.3 kB/s eta 0:00:01
#    -------------------------- ------------- 194.6/294.9 kB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 286.7/294.9 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 1.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\admin\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install matlplotlib
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement matlplotlib (from versions: none)
# ERROR: No matching distribution found for matlplotlib
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\admin\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install warnings
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement warnings (from versions: none)
# ERROR: No matching distribution found for warnings
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\admin\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as pt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("synthetic_insurance_data.csv")
df
# Out:
#       age     sex    bmi  children smoker     region   charges
# 0      56    male  26.48         4    yes  northwest  28270.08
# 1      46  female  28.81         3     no  southwest   7332.36
# 2      32    male  25.45         4    yes  southwest  27614.02
# 3      60    male  30.20         2     no  northwest   8997.63
# 4      25    male  26.27         1     no  northwest   7002.02
# ...   ...     ...    ...       ...    ...        ...       ...
# 1333   60    male  30.27         3     no  southwest   8114.57
# 1334   63  female  31.15         0     no  southwest   8089.97
# 1335   21    male  26.64         2    yes  southwest  27111.21
# 1336   43    male  28.84         4     no  southeast   7744.15
# 1337   46  female  26.02         2     no  northeast   7816.58
#
# [1338 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     41.036622    29.834469     2.076981  11760.932862
# std      13.528861     5.913797     1.389961   8163.070151
# min      18.000000     9.170000     0.000000   3471.180000
# 25%      29.000000    25.802500     1.000000   7003.435000
# 50%      42.000000    30.020000     2.000000   8124.205000
# 75%      52.000000    33.850000     3.000000   9996.677500
# max      64.000000    46.390000     4.000000  31243.520000

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
import matplotlib.pyplot as plt
features = ['sex', 'smoker', 'region']

plt.subplots(figsize=(20, 10))
for i, col in enumerate(features):
    plt.subplot(1, 3, i + 1)

    x = df[col].value_counts()
    plt.pie(x.values,
            labels=x.index,
            autopct='%1.1f%%')

plt.show()

# This code is modified by Susobhan Akhuli

# %%
features = ['sex', 'children', 'smoker', 'region']

plt.subplots(figsize=(20, 10))
for i, col in enumerate(features):
    plt.subplot(2, 2, i + 1)
    df.groupby(col)['charges'].mean().astype(float).plot.bar()
plt.show()

# This code is modified by Susobhan Akhuli

# %%
import seaborn as sns

features = ['age', 'bmi']

plt.subplots(figsize=(17, 7))
for i, col in enumerate(features):
    plt.subplot(1, 2, i + 1)
    sns.scatterplot(data=df, x=col,
                   y='charges',
                   hue='smoker')
plt.show()

# This code is modified by Susobhan Akhuli

# %%
df.drop_duplicates(inplace=True)
sns.boxplot(df['age'])
# Out:
# <Axes: ylabel='age'>

# %%
sns.boxplot(df['bmi'])
# Out:
# <Axes: ylabel='bmi'>

# %%
Q1=df['bmi'].quantile(0.25)
Q2=df['bmi'].quantile(0.5)
Q3=df['bmi'].quantile(0.75)
iqr=Q3-Q1
lowlim=Q1-1.5*iqr
upplim=Q3+1.5*iqr
print(lowlim)
print(upplim)
# Out:
# 13.731250000000003
# 45.92125

# %%
pip install feature_engine
# Out:
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------------------------- ------------ 41.0/60.8 kB 653.6 kB/s eta 0:00:01
#      ---------------------------------------- 60.8/60.8 kB 1.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/378.6 kB ? eta -:--:--
#    ----------- ---------------------------- 112.6/378.6 kB 3.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 337.9/378.6 kB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 378.6/378.6 kB 3.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#     --------------------------------------- 0.2/11.1 MB 5.0 MB/s eta 0:00:03
#    - -------------------------------------- 0.5/11.1 MB 4.8 MB/s eta 0:00:03
#    -- ------------------------------------- 0.7/11.1 MB 4.6 MB/s eta 0:00:03
#    --- ------------------------------------ 1.0/11.1 MB 5.0 MB/s eta 0:00:03
# ...

# %%
from feature_engine.outliers import ArbitraryOutlierCapper
arb=ArbitraryOutlierCapper(min_capping_dict={'bmi':13.6749},max_capping_dict={'bmi':47.315})
df[['bmi']]=arb.fit_transform(df[['bmi']])
sns.boxplot(df['bmi'])
# Out:
# <Axes: ylabel='bmi'>

# %%
df['bmi'].skew()
df['age'].skew()
# Out:
# np.float64(-0.05148670430257451)

# %%
df['sex']=df['sex'].map({'male':0,'female':1})
df['smoker']=df['smoker'].map({'yes':1,'no':0})
df['region']=df['region'].map({'northwest':0, 'northeast':1,'southeast':2,'southwest':3})

# %%
df.corr()
# Out:
#                age  sex       bmi  children  smoker  region   charges
# age       1.000000  NaN -0.031455  0.013692     NaN     NaN  0.107388
# sex            NaN  NaN       NaN       NaN     NaN     NaN       NaN
# bmi      -0.031455  NaN  1.000000 -0.042376     NaN     NaN  0.038821
# children  0.013692  NaN -0.042376  1.000000     NaN     NaN  0.060452
# smoker         NaN  NaN       NaN       NaN     NaN     NaN       NaN
# region         NaN  NaN       NaN       NaN     NaN     NaN       NaN
# charges   0.107388  NaN  0.038821  0.060452     NaN     NaN  1.000000

# %% [markdown]
# #Model Development

# %%
X=df.drop(['charges'],axis=1)
Y=df[['charges']]
from sklearn.linear_model import LinearRegression,Lasso
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
l1=[]
l2=[]
l3=[]
cvs=0
for i in range(40,50):
 xtrain,xtest,ytrain,ytest=train_test_split(X,Y,test_size=0.2,random_state=i)
 lrmodel=LinearRegression()
 lrmodel.fit(xtrain,ytrain)
 l1.append(lrmodel.score(xtrain,ytrain))
 l2.append(lrmodel.score(xtest,ytest))
 cvs=(cross_val_score(lrmodel,X,Y,cv=5,)).mean()
 l3.append(cvs)
 df1=pd.DataFrame({'train acc':l1,'test acc':l2,'cvs':l3})
 df1

# This code is modified by Susobhan Akhuli
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 7
#       5 from sklearn.ensemble import RandomForestRegressor
#       6 from sklearn.ensemble import GradientBoostingRegressor
# ----> 7 from xgboost import XGBRegressor
#       8 from sklearn.model_selection import train_test_split
#       9 from sklearn.model_selection import cross_val_score
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
pip install xgboost
# Out:
# ...
#    ---------------------------------------- 0.0/150.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/150.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/150.0 MB 435.7 kB/s eta 0:05:45
#    ---------------------------------------- 0.1/150.0 MB 837.8 kB/s eta 0:02:59
#    ---------------------------------------- 0.2/150.0 MB 1.5 MB/s eta 0:01:44
#    ---------------------------------------- 0.5/150.0 MB 2.8 MB/s eta 0:00:54
#    ---------------------------------------- 0.8/150.0 MB 3.2 MB/s eta 0:00:48
#    ---------------------------------------- 1.1/150.0 MB 3.8 MB/s eta 0:00:40
#    ---------------------------------------- 1.5/150.0 MB 4.2 MB/s eta 0:00:36
#    ---------------------------------------- 1.8/150.0 MB 4.5 MB/s eta 0:00:34
#     --------------------------------------- 2.0/150.0 MB 4.6 MB/s eta 0:00:33
#     --------------------------------------- 2.3/150.0 MB 4.5 MB/s eta 0:00:33
# ...

# %%
X=df.drop(['charges'],axis=1)
Y=df[['charges']]
from sklearn.linear_model import LinearRegression,Lasso
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
l1=[]
l2=[]
l3=[]
cvs=0
for i in range(40,50):
 xtrain,xtest,ytrain,ytest=train_test_split(X,Y,test_size=0.2,random_state=i)
 lrmodel=LinearRegression()
 lrmodel.fit(xtrain,ytrain)
 l1.append(lrmodel.score(xtrain,ytrain))
 l2.append(lrmodel.score(xtest,ytest))
 cvs=(cross_val_score(lrmodel,X,Y,cv=5,)).mean()
 l3.append(cvs)
 df1=pd.DataFrame({'train acc':l1,'test acc':l2,'cvs':l3})
 df1

# This code is modified by Susobhan Akhuli
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 17
#      15 xtrain,xtest,ytrain,ytest=train_test_split(X,Y,test_size=0.2,random_state=i)
#      16 lrmodel=LinearRegression()
# ---> 17 lrmodel.fit(xtrain,ytrain)
#      18 l1.append(lrmodel.score(xtrain,ytrain))
#      19 l2.append(lrmodel.score(xtest,ytest))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# ...

# %%
# Drop rows with missing values in X and Y
X_clean = X.dropna()
Y_clean = Y.loc[X_clean.index]

# Proceed with train-test split and model training
xtrain, xtest, ytrain, ytest = train_test_split(X_clean, Y_clean, test_size=0.2, random_state=i)
lrmodel = LinearRegression()
lrmodel.fit(xtrain, ytrain)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 6
#       3 Y_clean = Y.loc[X_clean.index]
#       5 # Proceed with train-test split and model training
# ----> 6 xtrain, xtest, ytrain, ytest = train_test_split(X_clean, Y_clean, test_size=0.2, random_state=i)
#       7 lrmodel = LinearRegression()
#       8 lrmodel.fit(xtrain, ytrain)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
# ...

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression

# Initialize lists to store results
l1 = []
l2 = []
l3 = []

# Loop through random states for train-test split
for i in range(40, 50):
    xtrain, xtest, ytrain, ytest = train_test_split(X, Y, test_size=0.2, random_state=i)
    
    # Initialize and fit the Linear Regression model
    lrmodel = LinearRegression()
    lrmodel.fit(xtrain, ytrain)
    
    # Append training and testing scores
    l1.append(lrmodel.score(xtrain, ytrain))
    l2.append(lrmodel.score(xtest, ytest))
    
    # Perform cross-validation and append the mean score
    cvs = cross_val_score(lrmodel, X, Y, cv=5).mean()
    l3.append(cvs)

# Create a DataFrame to store the results
df1 = pd.DataFrame({'train acc': l1, 'test acc': l2, 'cvs': l3})
df1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 15
#      13 # Initialize and fit the Linear Regression model
#      14 lrmodel = LinearRegression()
# ---> 15 lrmodel.fit(xtrain, ytrain)
#      17 # Append training and testing scores
#      18 l1.append(lrmodel.score(xtrain, ytrain))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# ...

# %%
# This code is modified by Susobhan Akhuli

# %%
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression
import pandas as pd

# Impute missing values in X
imputer = SimpleImputer(strategy='mean')
X_imputed = pd.DataFrame(imputer.fit_transform(X), columns=X.columns)

# Initialize lists to store results
l1 = []
l2 = []
l3 = []

# Loop through random states for train-test split
for i in range(40, 50):
    xtrain, xtest, ytrain, ytest = train_test_split(X_imputed, Y, test_size=0.2, random_state=i)
    
    # Initialize and fit the Linear Regression model
    lrmodel = LinearRegression()
    lrmodel.fit(xtrain, ytrain)
    
    # Append training and testing scores
    l1.append(lrmodel.score(xtrain, ytrain))
    l2.append(lrmodel.score(xtest, ytest))
    
    # Perform cross-validation and append the mean score
    cvs = cross_val_score(lrmodel, X_imputed, Y, cv=5).mean()
    l3.append(cvs)

# Create a DataFrame to store the results
df1 = pd.DataFrame({'train acc': l1, 'test acc': l2, 'cvs': l3})
df1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 8
#       6 # Impute missing values in X
#       7 imputer = SimpleImputer(strategy='mean')
# ----> 8 X_imputed = pd.DataFrame(imputer.fit_transform(X), columns=X.columns)
#      10 # Initialize lists to store results
#      11 l1 = []
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:827, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     816         mgr = dict_to_mgr(
#     817             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     818             # attribute "name"
#    (...)    824             copy=_copy,
#     825         )
#     826     else:
# --> 827         mgr = ndarray_to_mgr(
#     828             data,
#     829             index,
# ...

# %%
from sklearn.impute import SimpleImputer

# Separate numeric and categorical columns
numeric_cols = X.select_dtypes(include=['int64', 'float64']).columns
categorical_cols = X.select_dtypes(exclude=['int64', 'float64']).columns

# Impute only numeric columns
imputer = SimpleImputer(strategy='mean')
X_numeric_imputed = pd.DataFrame(imputer.fit_transform(X[numeric_cols]), columns=numeric_cols)

# Combine with categorical columns
X_final = pd.concat([X_numeric_imputed, X[categorical_cols].reset_index(drop=True)], axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 9
#       7 # Impute only numeric columns
#       8 imputer = SimpleImputer(strategy='mean')
# ----> 9 X_numeric_imputed = pd.DataFrame(imputer.fit_transform(X[numeric_cols]), columns=numeric_cols)
#      11 # Combine with categorical columns
#      12 X_final = pd.concat([X_numeric_imputed, X[categorical_cols].reset_index(drop=True)], axis=1)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:827, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     816         mgr = dict_to_mgr(
#     817             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     818             # attribute "name"
#    (...)    824             copy=_copy,
#     825         )
#     826     else:
# ...

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# 1. Label encode 'sex' and 'smoker'
X_final['sex'] = X_final['sex'].map({'male': 0, 'female': 1})
X_final['smoker'] = X_final['smoker'].map({'no': 0, 'yes': 1})

# 2. One-hot encode 'region'
region_encoded = pd.get_dummies(X_final['region'], prefix='region')

# 3. Drop original 'region' and add encoded
X_final = X_final.drop('region', axis=1)
X_final = pd.concat([X_final, region_encoded], axis=1)

X_final.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 4
#       1 from sklearn.preprocessing import OneHotEncoder, LabelEncoder
#       3 # 1. Label encode 'sex' and 'smoker'
# ----> 4 X_final['sex'] = X_final['sex'].map({'male': 0, 'female': 1})
#       5 X_final['smoker'] = X_final['smoker'].map({'no': 0, 'yes': 1})
#       7 # 2. One-hot encode 'region'
#
# NameError: name 'X_final' is not defined

# %%
import pandas as pd
from sklearn.impute import SimpleImputer

# Assuming df is your original DataFrame with target 'charges'
X = df.drop('charges', axis=1)
y = df['charges']

# Separate numeric and categorical columns
numeric_cols = X.select_dtypes(include=['int64', 'float64']).columns.tolist()
categorical_cols = [col for col in X.columns if col not in numeric_cols]

# Impute numeric columns
imputer = SimpleImputer(strategy='mean')
X_numeric = pd.DataFrame(imputer.fit_transform(X[numeric_cols]), columns=numeric_cols)

# Concatenate categorical columns back (no imputation here, assuming no missing values)
X_categorical = X[categorical_cols].reset_index(drop=True)
X_combined = pd.concat([X_numeric, X_categorical], axis=1)

# Label encode binary columns
X_combined['sex'] = X_combined['sex'].map({'male': 0, 'female': 1})
X_combined['smoker'] = X_combined['smoker'].map({'no': 0, 'yes': 1})

# One-hot encode region
region_encoded = pd.get_dummies(X_combined['region'], prefix='region')
X_final = pd.concat([X_combined.drop('region', axis=1), region_encoded], axis=1)

# Final X and y
print("✅ Final shape of X:", X_final.shape)
print("🎯 Ready to model!")

# Optional: preview
X_final.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 14
#      12 # Impute numeric columns
#      13 imputer = SimpleImputer(strategy='mean')
# ---> 14 X_numeric = pd.DataFrame(imputer.fit_transform(X[numeric_cols]), columns=numeric_cols)
#      16 # Concatenate categorical columns back (no imputation here, assuming no missing values)
#      17 X_categorical = X[categorical_cols].reset_index(drop=True)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:827, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     816         mgr = dict_to_mgr(
#     817             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     818             # attribute "name"
#    (...)    824             copy=_copy,
#     825         )
# ...

# %%
print("Numeric columns inferred:")
print(numeric_cols)

print("\nData types of those columns:")
print(X[numeric_cols].dtypes)

print("\nCheck first few rows for unexpected values:")
print(X[numeric_cols].head())
# Out:
# Numeric columns inferred:
# ['age', 'sex', 'bmi', 'children', 'smoker', 'region']
#
# Data types of those columns:
# age           int64
# sex         float64
# bmi         float64
# children      int64
# smoker      float64
# region      float64
# dtype: object
#
# Check first few rows for unexpected values:
#    age  sex    bmi  children  smoker  region
# 0   56  NaN  26.48         4     NaN     NaN
# 1   46  NaN  28.81         3     NaN     NaN
# 2   32  NaN  25.45         4     NaN     NaN
# 3   60  NaN  30.20         2     NaN     NaN
# 4   25  NaN  26.27         1     NaN     NaN

# %%
# Step 1: Re-load original data (if needed)
# df = pd.read_csv("your_dataset.csv")

# Step 2: Separate X and y
X = df.drop("charges", axis=1)
y = df["charges"]

# Step 3: Restore original categorical columns
categorical_cols = ['sex', 'smoker', 'region']
numeric_cols = ['age', 'bmi', 'children']

# Step 4: Impute numeric columns
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='mean')
X_numeric = pd.DataFrame(imputer.fit_transform(X[numeric_cols]), columns=numeric_cols)

# Step 5: Impute categorical columns (if needed)
X_categorical = X[categorical_cols].copy()
X_categorical.fillna(method='ffill', inplace=True)  # Or use most_frequent with SimpleImputer

# Step 6: Encode categorical columns
X_categorical['sex'] = X_categorical['sex'].map({'male': 0, 'female': 1})
X_categorical['smoker'] = X_categorical['smoker'].map({'no': 0, 'yes': 1})
region_encoded = pd.get_dummies(X_categorical['region'], prefix='region')
X_categorical = pd.concat([X_categorical.drop('region', axis=1), region_encoded], axis=1)

# Step 7: Final Dataset
X_final = pd.concat([X_numeric, X_categorical], axis=1)

# ✅ X_final is ready!
print("✅ Final shape:", X_final.shape)
X_final.head()
# Out:
# ✅ Final shape: (1338, 5)
#     age    bmi  children  sex  smoker
# 0  56.0  26.48       4.0  NaN     NaN
# 1  46.0  28.81       3.0  NaN     NaN
# 2  32.0  25.45       4.0  NaN     NaN
# 3  60.0  30.20       2.0  NaN     NaN
# 4  25.0  26.27       1.0  NaN     NaN

# %%
import pandas as pd
from sklearn.impute import SimpleImputer

# Assume df is your DataFrame
# Step 1: Separate numeric and categorical
numeric_cols = ['age', 'bmi', 'children']
categorical_cols = ['sex', 'smoker']

# Step 2: Impute numeric columns
num_imputer = SimpleImputer(strategy='mean')
df[numeric_cols] = num_imputer.fit_transform(df[numeric_cols])

# Step 3: Impute categorical columns using most frequent (mode)
cat_imputer = SimpleImputer(strategy='most_frequent')
df[categorical_cols] = cat_imputer.fit_transform(df[categorical_cols])

# Step 4: Encode binary categorical columns
df['sex'] = df['sex'].map({'male': 0, 'female': 1})
df['smoker'] = df['smoker'].map({'no': 0, 'yes': 1})

# ✅ Final dataset ready for modeling
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3460\3290576239.py in ?()
#      11 df[numeric_cols] = num_imputer.fit_transform(df[numeric_cols])
#      12
#      13 # Step 3: Impute categorical columns using most frequent (mode)
#      14 cat_imputer = SimpleImputer(strategy='most_frequent')
# ---> 15 df[categorical_cols] = cat_imputer.fit_transform(df[categorical_cols])
#      16
#      17 # Step 4: Encode binary categorical columns
#      18 df['sex'] = df['sex'].map({'male': 0, 'female': 1})
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4295
#    4296         if isinstance(key, DataFrame) or getattr(key, "ndim", None) == 2:
#    4297             self._setitem_frame(key, value)
# ...

# %%
import numpy as np

# Number of rows
n_rows = 1338

# Set random seed for reproducibility
np.random.seed(42)

# Generate synthetic but realistic data
ages = np.random.randint(18, 65, size=n_rows)
bmis = np.round(np.random.normal(30, 6, size=n_rows), 2)
children = np.random.randint(0, 5, size=n_rows)
sex = np.random.choice(['male', 'female'], size=n_rows)
smoker = np.random.choice(['yes', 'no'], size=n_rows, p=[0.2, 0.8])
region = np.random.choice(['northeast', 'northwest', 'southeast', 'southwest'], size=n_rows)

# Simulate charges based on features
charges = (
    2500 +
    (ages * 45) +
    (bmis * 120) +
    (children * 350) +
    (smoker == 'yes') * 18000 +
    np.random.normal(0, 1500, size=n_rows)
)
charges = np.round(charges, 2)

# Create DataFrame
final_df = pd.DataFrame({
    'age': ages,
    'sex': sex,
    'bmi': bmis,
    'children': children,
    'smoker': smoker,
    'region': region,
    'charges': charges
})

# Save to CSV
csv_final_path = "/mnt/data/synthetic_insurance_dataset.csv"
final_df.to_csv(csv_final_path, index=False)

csv_final_path
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[33], line 41
#      39 # Save to CSV
#      40 csv_final_path = "/mnt/data/synthetic_insurance_dataset.csv"
# ---> 41 final_df.to_csv(csv_final_path, index=False)
#      43 csv_final_path
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
import os
import numpy as np
import pandas as pd

# Define path to save the file
save_dir = r"C:\Users\admin\Desktop\Insurance_policy_dataset"
save_path = os.path.join(save_dir, "clean_insurance_dataset.csv")

# Create the folder if it doesn't exist
os.makedirs(save_dir, exist_ok=True)

# Set random seed for reproducibility
np.random.seed(42)

# Number of samples
n_rows = 1338

# Generate synthetic data
ages = np.random.randint(18, 65, size=n_rows)
bmis = np.round(np.random.normal(30, 6, size=n_rows), 2)
children = np.random.randint(0, 5, size=n_rows)
sex = np.random.choice(['male', 'female'], size=n_rows)
smoker = np.random.choice(['yes', 'no'], size=n_rows, p=[0.2, 0.8])
region = np.random.choice(['northeast', 'northwest', 'southeast', 'southwest'], size=n_rows)

# Generate charges based on logic
charges = (
    2500 +
    (ages * 45) +
    (bmis * 120) +
    (children * 350) +
    (smoker == 'yes') * 18000 +
    np.random.normal(0, 1500, size=n_rows)
)
charges = np.round(charges, 2)

# Create DataFrame
df = pd.DataFrame({
    'age': ages,
    'sex': sex,
    'bmi': bmis,
    'children': children,
    'smoker': smoker,
    'region': region,
    'charges': charges
})

# Save to CSV
df.to_csv(save_path, index=False)
print(f"✅ Dataset saved successfully at:\n{save_path}")
# Out:
# ✅ Dataset saved successfully at:
# C:\Users\admin\Desktop\Insurance_policy_dataset\clean_insurance_dataset.csv

# %%
X=df.drop(['charges'],axis=1)
Y=df[['charges']]
from sklearn.linear_model import LinearRegression,Lasso
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
l1=[]
l2=[]
l3=[]
cvs=0
for i in range(40,50):
 xtrain,xtest,ytrain,ytest=train_test_split(X,Y,test_size=0.2,random_state=i)
 lrmodel=LinearRegression()
 lrmodel.fit(xtrain,ytrain)
 l1.append(lrmodel.score(xtrain,ytrain))
 l2.append(lrmodel.score(xtest,ytest))
 cvs=(cross_val_score(lrmodel,X,Y,cv=5,)).mean()
 l3.append(cvs)
 df1=pd.DataFrame({'train acc':l1,'test acc':l2,'cvs':l3})
 df1

# This code is modified by Susobhan Akhuli
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3460\3361444322.py in ?()
#      13 cvs=0
#      14 for i in range(40,50):
#      15  xtrain,xtest,ytrain,ytest=train_test_split(X,Y,test_size=0.2,random_state=i)
#      16  lrmodel=LinearRegression()
# ---> 17  lrmodel.fit(xtrain,ytrain)
#      18  l1.append(lrmodel.score(xtrain,ytrain))
#      19  l2.append(lrmodel.score(xtest,ytest))
#      20  cvs=(cross_val_score(lrmodel,X,Y,cv=5,)).mean()
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1385                 skip_parameter_validation=(
#    1386                     prefer_skip_nested_validation or global_skip_validation
#    1387                 )
#    1388             ):
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# 1. Load your clean dataset
df = pd.read_csv(r"C:\Users\admin\Desktop\Insurance_policy_dataset\clean_insurance_dataset.csv")

# 2. Encode categorical features
df['sex'] = df['sex'].map({'male': 0, 'female': 1})
df['smoker'] = df['smoker'].map({'no': 0, 'yes': 1})
df = pd.get_dummies(df, columns=['region'], drop_first=True)

# 3. Split into features (X) and target (y)
X = df.drop("charges", axis=1)
Y = df["charges"]

# 4. Train Linear Regression and evaluate
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score

l1 = []
l2 = []
for i in range(40, 50):
    xtrain, xtest, ytrain, ytest = train_test_split(X, Y, test_size=0.2, random_state=i)
    
    lrmodel = LinearRegression()
    lrmodel.fit(xtrain, ytrain)

    train_score = lrmodel.score(xtrain, ytrain)
    test_score = lrmodel.score(xtest, ytest)

    l1.append(train_score)
    l2.append(test_score)

    print(f"Random State {i} -> Train R²: {train_score:.3f}, Test R²: {test_score:.3f}")

# 5. Cross-validation
cvs = cross_val_score(LinearRegression(), X, Y, cv=5).mean()
print(f"\nAverage Cross-Validation Score (R²): {cvs:.3f}")
# Out:
# Random State 40 -> Train R²: 0.956, Test R²: 0.957
# Random State 41 -> Train R²: 0.956, Test R²: 0.955
# Random State 42 -> Train R²: 0.957, Test R²: 0.952
# Random State 43 -> Train R²: 0.956, Test R²: 0.958
# Random State 44 -> Train R²: 0.956, Test R²: 0.956
# Random State 45 -> Train R²: 0.956, Test R²: 0.957
# Random State 46 -> Train R²: 0.956, Test R²: 0.957
# Random State 47 -> Train R²: 0.956, Test R²: 0.955
# Random State 48 -> Train R²: 0.956, Test R²: 0.956
# Random State 49 -> Train R²: 0.956, Test R²: 0.958
#
# Average Cross-Validation Score (R²): 0.955

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score

# Load dataset
df = pd.read_csv(r"C:\Users\admin\Desktop\Insurance_policy_dataset\clean_insurance_dataset.csv")

# Encode categorical columns
df['sex'] = df['sex'].map({'male': 0, 'female': 1})
df['smoker'] = df['smoker'].map({'no': 0, 'yes': 1})
df = pd.get_dummies(df, columns=['region'], drop_first=True)

# Feature matrix and target variable
X = df.drop(['charges'], axis=1)
Y = df['charges']  # Use Series, not DataFrame

from sklearn.linear_model import LinearRegression
l1 = []
l2 = []
l3 = []

for i in range(40, 50):
    xtrain, xtest, ytrain, ytest = train_test_split(X, Y, test_size=0.2, random_state=i)

    lrmodel = LinearRegression()
    lrmodel.fit(xtrain, ytrain)

    l1.append(lrmodel.score(xtrain, ytrain))
    l2.append(lrmodel.score(xtest, ytest))
    l3.append(cross_val_score(lrmodel, X, Y, cv=5).mean())

# Create final result DataFrame
df1 = pd.DataFrame({
    'Random State': list(range(40, 50)),
    'Train R²': l1,
    'Test R²': l2,
    'Cross-Val R²': l3
})

print(df1)
# Out:
#    Random State  Train R²   Test R²  Cross-Val R²
# 0            40  0.955904  0.956873      0.954872
# 1            41  0.956449  0.954933      0.954872
# 2            42  0.957013  0.951918      0.954872
# 3            43  0.955695  0.957517      0.954872
# 4            44  0.956154  0.956142      0.954872
# 5            45  0.955821  0.956879      0.954872
# 6            46  0.956056  0.956645      0.954872
# 7            47  0.956442  0.954618      0.954872
# 8            48  0.956274  0.955780      0.954872
# 9            49  0.955552  0.957815      0.954872

# %%
xtrain,xtest,ytrain,ytest=train_test_split(X,Y,test_size=0.2,random_state=42)
lrmodel=LinearRegression()
lrmodel.fit(xtrain,ytrain)
print(lrmodel.score(xtrain,ytrain))
print(lrmodel.score(xtest,ytest))
print(cross_val_score(lrmodel,X,Y,cv=5,).mean())
# Out:
# 0.9570133954178547
# 0.9519179693142579
# 0.9548721704508278

# %%
from sklearn.metrics import r2_score
svrmodel=SVR()
svrmodel.fit(xtrain,ytrain)
ypredtrain1=svrmodel.predict(xtrain)
ypredtest1=svrmodel.predict(xtest)
print(r2_score(ytrain,ypredtrain1))
print(r2_score(ytest,ypredtest1))
print(cross_val_score(svrmodel,X,Y,cv=5,).mean())
# Out:
# -0.17547488820926183
# -0.11429181708435032
# -0.16915171462410825

# %%
rfmodel=RandomForestRegressor(random_state=42)
rfmodel.fit(xtrain,ytrain)
ypredtrain2=rfmodel.predict(xtrain)
ypredtest2=rfmodel.predict(xtest)
print(r2_score(ytrain,ypredtrain2))
print(r2_score(ytest,ypredtest2))
print(cross_val_score(rfmodel,X,Y,cv=5,).mean())
from sklearn.model_selection import GridSearchCV
estimator=RandomForestRegressor(random_state=42)
param_grid={'n_estimators':[10,40,50,98,100,120,150]}
grid=GridSearchCV(estimator,param_grid,scoring="r2",cv=5)
grid.fit(xtrain,ytrain)
print(grid.best_params_)
rfmodel=RandomForestRegressor(random_state=42,n_estimators=120)
rfmodel.fit(xtrain,ytrain)
ypredtrain2=rfmodel.predict(xtrain)
ypredtest2=rfmodel.predict(xtest)
print(r2_score(ytrain,ypredtrain2))
print(r2_score(ytest,ypredtest2))
print(cross_val_score(rfmodel,X,Y,cv=5,).mean())
# Out:
# 0.993006681538937
# 0.9429671782877189
# 0.9475641759204427
# {'n_estimators': 150}
# 0.9930500362199544
# 0.9430242568570459
# 0.9477633621162191

# %%
gbmodel=GradientBoostingRegressor()
gbmodel.fit(xtrain,ytrain)
ypredtrain3=gbmodel.predict(xtrain)
ypredtest3=gbmodel.predict(xtest)
print(r2_score(ytrain,ypredtrain3))
print(r2_score(ytest,ypredtest3))
print(cross_val_score(gbmodel,X,Y,cv=5,).mean())
from sklearn.model_selection import GridSearchCV
estimator=GradientBoostingRegressor()
param_grid={'n_estimators':[10,15,19,20,21,50],'learning_rate':[0.1,0.19,0.2,0.21,0.8,1]}
grid=GridSearchCV(estimator,param_grid,scoring="r2",cv=5)
grid.fit(xtrain,ytrain)
print(grid.best_params_)
gbmodel=GradientBoostingRegressor(n_estimators=19,learning_rate=0.2)
gbmodel.fit(xtrain,ytrain)
ypredtrain3=gbmodel.predict(xtrain)
ypredtest3=gbmodel.predict(xtest)
print(r2_score(ytrain,ypredtrain3))
print(r2_score(ytest,ypredtest3))
print(cross_val_score(gbmodel,X,Y,cv=5,).mean())
# Out:
# 0.9681612605479191
# 0.9470152304004876
# 0.9512402368795131
# {'learning_rate': 0.21, 'n_estimators': 21}
# 0.9616919923191644
# 0.9493182855994657
# 0.9520862017216316

# %%
xgmodel=XGBRegressor()
xgmodel.fit(xtrain,ytrain)
ypredtrain4=xgmodel.predict(xtrain)
ypredtest4=xgmodel.predict(xtest)
print(r2_score(ytrain,ypredtrain4))
print(r2_score(ytest,ypredtest4))
print(cross_val_score(xgmodel,X,Y,cv=5,).mean())
from sklearn.model_selection import GridSearchCV
estimator=XGBRegressor()
param_grid={'n_estimators':[10,15,20,40,50],'max_depth':[3,4,5],'gamma':[0,0.15,0.3,0.5,1]}
grid=GridSearchCV(estimator,param_grid,scoring="r2",cv=5)
grid.fit(xtrain,ytrain)
print(grid.best_params_)
xgmodel=XGBRegressor(n_estimators=15,max_depth=3,gamma=0)
xgmodel.fit(xtrain,ytrain)
ypredtrain4=xgmodel.predict(xtrain)
ypredtest4=xgmodel.predict(xtest)
print(r2_score(ytrain,ypredtrain4))
print(r2_score(ytest,ypredtest4))
print(cross_val_score(xgmodel,X,Y,cv=5,).mean())
# Out:
# 0.9982131286784937
# 0.925342942796051
# 0.9368979261809928
# {'gamma': 0, 'max_depth': 3, 'n_estimators': 15}
# 0.9619142186084095
# 0.9484644388983928
# 0.9521886560132529

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor

# Load your preprocessed data
df = pd.read_csv(r"C:\Users\admin\Desktop\Insurance_policy_dataset\clean_insurance_dataset.csv")

# Encode categorical columns
df['sex'] = df['sex'].map({'male': 0, 'female': 1})
df['smoker'] = df['smoker'].map({'no': 0, 'yes': 1})
df = pd.get_dummies(df, columns=['region'], drop_first=True)

# Split features and target
X = df.drop('charges', axis=1)
Y = df['charges']

# Train/Test Split
xtrain, xtest, ytrain, ytest = train_test_split(X, Y, test_size=0.2, random_state=42)

# Initialize models
models = {
    "LinearRegression": LinearRegression(),
    "SupportVectorMachine": SVR(),
    "RandomForest": RandomForestRegressor(n_estimators=100, random_state=42),
    "GradientBoost": GradientBoostingRegressor(random_state=42),
    "XGBoost": XGBRegressor(n_estimators=100, random_state=42, verbosity=0)
}

# Evaluate models
results = {
    "Model": [],
    "Train Accuracy": [],
    "Test Accuracy": [],
    "CV Score": []
}

for name, model in models.items():
    model.fit(xtrain, ytrain)
    train_score = model.score(xtrain, ytrain)
    test_score = model.score(xtest, ytest)
    cv_score = cross_val_score(model, X, Y, cv=5).mean()

    results["Model"].append(name)
    results["Train Accuracy"].append(round(train_score, 3))
    results["Test Accuracy"].append(round(test_score, 3))
    results["CV Score"].append(round(cv_score, 3))

# Create DataFrame
comparison_df = pd.DataFrame(results)
print(comparison_df)
# Out:
#                   Model  Train Accuracy  Test Accuracy  CV Score
# 0      LinearRegression           0.957          0.952     0.955
# 1  SupportVectorMachine          -0.175         -0.114    -0.169
# 2          RandomForest           0.993          0.943     0.948
# 3         GradientBoost           0.968          0.947     0.951
# 4               XGBoost           0.998          0.925     0.937

# %%
#Linear Regression is the best model for your dataset based on overall balanced performance across training, testing, and cross-validation accuracy.

# %%
feats=pd.DataFrame(data=grid.best_estimator_.feature_importances_,index=X.columns,columns=['Importance'])
feats
# Out:
#                   Importance
# age                 0.003658
# sex                 0.000000
# bmi                 0.003721
# children            0.004487
# smoker              0.986631
# region_northwest    0.000143
# region_southeast    0.000552
# region_southwest    0.000809

# %%
important_features=feats[feats['Importance']>0.01]
important_features
# Out:
#         Importance
# smoker    0.986631

# %%
df.drop(df['sex','region'],axis=1,inplace=True)
Xf=df.drop(df[['charges']],axis=1)
X=df.drop(df[['charges']],axis=1)
xtrain,xtest,ytrain,ytest=train_test_split(Xf,Y,test_size=0.2,random_state=42)
finalmodel=XGBRegressor(n_estimators=15,max_depth=3,gamma=0)
finalmodel.fit(xtrain,ytrain)
ypredtrain4=finalmodel.predict(xtrain)
ypredtest4=finalmodel.predict(xtest)
print(r2_score(ytrain,ypredtrain4))
print(r2_score(ytest,ypredtest4))
print(cross_val_score(finalmodel,X,Y,cv=5,).mean())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('sex', 'region')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
#Final Model

# %%
from xgboost import XGBRegressor
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split, cross_val_score

# Drop 'sex' and one-hot encoded region columns
cols_to_drop = ['sex'] + [col for col in df.columns if col.startswith('region')]
df.drop(cols_to_drop, axis=1, inplace=True)

# Prepare data
Xf = df.drop(['charges'], axis=1)
Y = df['charges']

# Train-test split
xtrain, xtest, ytrain, ytest = train_test_split(Xf, Y, test_size=0.2, random_state=42)

# Train XGBoost model
finalmodel = XGBRegressor(n_estimators=15, max_depth=3, gamma=0)
finalmodel.fit(xtrain, ytrain)

# Predictions
ypredtrain4 = finalmodel.predict(xtrain)
ypredtest4 = finalmodel.predict(xtest)

# Evaluation
print("Train R² Score:", r2_score(ytrain, ypredtrain4))
print("Test R² Score:", r2_score(ytest, ypredtest4))
print("CV Score (5-Fold):", cross_val_score(finalmodel, Xf, Y, cv=5).mean())
# Out:
# Train R² Score: 0.9620743069422172
# Test R² Score: 0.9490045080503051
# CV Score (5-Fold): 0.9520068092682992

# %%
# Save Model

# %%
pip install pickle
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\admin\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from pickle import dump
dump(finalmodel,open('insurancemodelf.pkl','wb'))

# %%
new_data=pd.DataFrame({'age':19,'sex':'male','bmi':27.9,'children':0,'smoker':'yes','region':'northeast'},index=[0])
new_data['smoker']=new_data['smoker'].map({'yes':1,'no':0})
new_data=new_data.drop(new_data[['sex','region']],axis=1)
finalmodel.predict(new_data)
# Out:
# array([24540.549], dtype=float32)
